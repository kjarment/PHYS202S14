# %% [markdown]
# # Project Euler 17

# %% [markdown]
# If the numbers 1 to 5 are written out in words: one, two, three, four, five, then there are 3 + 3 + 5 + 4 + 4 = 19 letters used in total.
#
# If all the numbers from 1 to 1000 (one thousand) inclusive were written out in words, how many letters would be used?
#
#
# NOTE: Do not count spaces or hyphens. For example, 342 (three hundred and forty-two) contains 23 letters and 115 (one hundred and fifteen) contains 20 letters. The use of "and" when writing out numbers is in compliance with British usage.

# %%
import numpy as np

# %%
#Dicitionary of words
thousand = "thousand"
hundred = "hundred"
ninety = "ninety"
eighty = "eighty"
seventy = "seventy"
sixty = "sixty"
fifty = "fifty"
forty = "forty"
thirty = "thirty"
twenty = "twenty"
nineteen = "nineteen"
eighteen = "eighteen"
seventeen = "seventeen"
sixteen = "sixteen"
fifteen = "fifteen"
fourteen = "fourteen"
thirteen = "thirteen"
twelve = "twelve"
eleven = "eleven"
ten = "ten"
nine = "nine"
eight = "eight"
seven = "seven"
six = "six"
five = "five"
four = "four"
three = "three"
two = "two"
one = "one"
zero = ""
andd = "and"

# %%
#Define a function that can take in a number and output the number as a word
def wordthousand(N):
    string = str(N)
    length = len(string)
    empty = ""
    
    if length == 4:
        char1 = string[0]
        char2 = string[1]
        char3 = string[2]
        char4 = string[3]
        
        if char1 == "9":
            empty += nine
        elif char1 == "8":
            empty += eight
        elif char1 == "7":
            empty += seven
        elif char1 == "6":
            empty += six
        elif char1 == "5":
            empty += five
        elif char1 == "4":
            empty += four
        elif char1 == "3":
            empty += three
        elif char1 == "2":
            empty += two
        elif char1 == "1":
            empty += one
        elif char1 == "0":
            empty += zero
        
        if char1 != "0":
            empty += thousand
        
        
        
        if char2 == "9":
            empty += nine
        elif char2 == "8":
            empty += eight
        elif char2 == "7":
            empty += seven
        elif char2 == "6":
            empty += six
        elif char2 == "5":
            empty += five
        elif char2 == "4":
            empty += four
        elif char2 == "3":
            empty += three
        elif char2 == "2":
            empty += two
        elif char2 == "1":
            empty += one
        elif char2 == "0":
            empty += zero
        
        if char2 != "0":
            empty += hundred
            empty += andd
        
        if char3 == "9":
            empty += ninety
        elif char3 == "8":
            empty += eighty
        elif char3 == "7":
            empty += seventy
        elif char3 == "6":
            empty += sixty
        elif char3 == "5":
            empty += fifty
        elif char3 == "4":
            empty += forty
        elif char3 == "3":
            empty += thirty
        elif char3 == "2":
            empty += twenty
        elif char3 == "1":
            
            
            if char4 == "9":
                empty += nineteen
                return empty
            elif char4 == "8":
                empty += eighteen
                return empty
            elif char4 == "7":
                empty += seventeen
                return empty
            elif char4 == "6":
                empty += sixteen
                return empty
            elif char4 == "5":
                empty += fifteen
                return empty
            elif char4 == "4":
                empty += fourteen
                return empty
            elif char4 == "3":
                empty += thirteen
                return empty
            elif char4 == "2":
                empty += twelve
                return empty
            elif char4 == "1":
                empty += eleven
                return empty
            elif char4 == "0":
                empty += ten
                return empty
        elif char3 == "0":
            empty += zero
            
            
        if char4 == "9":
            empty += nine
            return empty
        elif char4 == "8":
            empty += eight
            return empty
        elif char4 == "7":
            empty += seven
            return empty
        elif char4 == "6":
            empty += six
            return empty
        elif char4 == "5":
            empty += five
            return empty
        elif char4 == "4":
            empty += four
            return empty
        elif char4 == "3":
            empty += three
            return empty
        elif char4 == "2":
            empty += two
            return empty
        elif char4 == "1":
            empty += one
            return empty
        elif char4 == "0":
            empty += zero
            return empty
    
    
    if length == 3:
        char1 = string[0]
        char2 = string[1]
        char3 = string[2]
        
        if char1 == "9":
            empty += nine
        elif char1 == "8":
            empty += eight
        elif char1 == "7":
            empty += seven
        elif char1 == "6":
            empty += six
        elif char1 == "5":
            empty += five
        elif char1 == "4":
            empty += four
        elif char1 == "3":
            empty += three
        elif char1 == "2":
            empty += two
        elif char1 == "1":
            empty += one
        elif char1 == "0":
            empty += zero
        
        if char1 != "0":
            empty += hundred
            empty += andd
        
        if char2 == "9":
            empty += ninety
        elif char2 == "8":
            empty += eighty
        elif char2 == "7":
            empty += seventy
        elif char2 == "6":
            empty += sixty
        elif char2 == "5":
            empty += fifty
        elif char2 == "4":
            empty += forty
        elif char2 == "3":
            empty += thirty
        elif char2 == "2":
            empty += twenty
        elif char2 == "1":
            
            
            if char3 == "9":
                empty += nineteen
                return empty
            elif char3 == "8":
                empty += eighteen
                return empty
            elif char3 == "7":
                empty += seventeen
                return empty
            elif char3 == "6":
                empty += sixteen
                return empty
            elif char3 == "5":
                empty += fifteen
                return empty
            elif char3 == "4":
                empty += fourteen
                return empty
            elif char3 == "3":
                empty += thirteen
                return empty
            elif char3 == "2":
                empty += twelve
                return empty
            elif char3 == "1":
                empty += eleven
                return empty
            elif char3 == "0":
                empty += ten
                return empty
        elif char2 == "0":
            empty += zero
            
            
        if char3 == "9":
            empty += nine
            return empty
        elif char3 == "8":
            empty += eight
            return empty
        elif char3 == "7":
            empty += seven
            return empty
        elif char3 == "6":
            empty += six
            return empty
        elif char3 == "5":
            empty += five
            return empty
        elif char3 == "4":
            empty += four
            return empty
        elif char3 == "3":
            empty += three
            return empty
        elif char3 == "2":
            empty += two
            return empty
        elif char3 == "1":
            empty += one
            return empty
        elif char3 == "0":
            empty += zero
            return empty
        
        
    if length == 2:
        char1 = string[0]
        char2 = string[1]
        
        
        if char1 == "9":
            empty += ninety
        elif char1 == "8":
            empty += eighty
        elif char1 == "7":
            empty += seventy
        elif char1 == "6":
            empty += sixty
        elif char1 == "5":
            empty += fifty
        elif char1 == "4":
            empty += forty
        elif char1 == "3":
            empty += thirty
        elif char1 == "2":
            empty += twenty
        elif char1 == "1":
            
            
            if char2 == "9":
                empty += nineteen
                return empty
            elif char2 == "8":
                empty += eighteen
                return empty
            elif char2 == "7":
                empty += seventeen
                return empty
            elif char2 == "6":
                empty += sixteen
                return empty
            elif char2 == "5":
                empty += fifteen
                return empty
            elif char2 == "4":
                empty += fourteen
                return empty
            elif char2 == "3":
                empty += thirteen
                return empty
            elif char2 == "2":
                empty += twelve
                return empty
            elif char2 == "1":
                empty += eleven
                return empty
            elif char2 == "0":
                empty += ten
                return empty
        elif char1 == "0":
            empty += zero
            
            
        if char2 == "9":
            empty += nine
            return empty
        elif char2 == "8":
            empty += eight
            return empty
        elif char2 == "7":
            empty += seven
            return empty
        elif char2 == "6":
            empty += six
            return empty
        elif char2 == "5":
            empty += five
            return empty
        elif char2 == "4":
            empty += four
            return empty
        elif char2 == "3":
            empty += three
            return empty
        elif char2 == "2":
            empty += two
            return empty
        elif char2 == "1":
            empty += one
            return empty
        elif char2 == "0":
            empty += zero
            return empty
        
        
    if length == 1:
        char1 = string[0]
        
        if char1 == "9":
            empty += nine
            return empty
        elif char1 == "8":
            empty += eight
            return empty
        elif char1 == "7":
            empty += seven
            return empty
        elif char1 == "6":
            empty += six
            return empty
        elif char1 == "5":
            empty += five
            return empty
        elif char1 == "4":
            empty += four
            return empty
        elif char1 == "3":
            empty += three
            return empty
        elif char1 == "2":
            empty += two
            return empty
        elif char1 == "1":
            empty += one
            return empty
        elif char1 == "0":
            empty += zero
            return empty

# %%
def wordcount(N):
    arrN = np.arange(N) + 1
    count = 0
    
    for i in arrN:
        string  = wordthousand(i)
        length = len(string)
        count += length
        
    return count

print wordcount(5)
print wordcount(1000)
print wordcount(9999)
# Out:
# 19
# 21151
# 319400
